# %% [markdown]
# ## Exception Handling

# %%
import builtins

# %%
dir(builtins)
# Out:
# ['ArithmeticError',
#  'AssertionError',
#  'AttributeError',
#  'BaseException',
#  'BaseExceptionGroup',
#  'BlockingIOError',
#  'BrokenPipeError',
#  'BufferError',
#  'BytesWarning',
#  'ChildProcessError',
#  'ConnectionAbortedError',
#  'ConnectionError',
#  'ConnectionRefusedError',
#  'ConnectionResetError',
#  'DeprecationWarning',
#  'EOFError',
#  'Ellipsis',
#  'EncodingWarning',
#  'EnvironmentError',
#  'Exception',
#  'ExceptionGroup',
#  'False',
#  'FileExistsError',
#  'FileNotFoundError',
#  'FloatingPointError',
#  'FutureWarning',
#  'GeneratorExit',
#  'IOError',
#  'ImportError',
#  'ImportWarning',
#  'IndentationError',
#  'IndexError',
#  'InterruptedError',
#  'IsADirectoryError',
#  'KeyError',
#  'KeyboardInterrupt',
#  'LookupError',
#  'MemoryError',
#  'ModuleNotFoundError',
#  'NameError',
#  'None',
#  'NotADirectoryError',
#  'NotImplemented',
#  'NotImplementedError',
#  'OSError',
#  'OverflowError',
#  'PendingDeprecationWarning',
#  'PermissionError',
#  'ProcessLookupError',
#  'RecursionError',
#  'ReferenceError',
#  'ResourceWarning',
#  'RuntimeError',
#  'RuntimeWarning',
#  'StopAsyncIteration',
#  'StopIteration',
#  'SyntaxError',
#  'SyntaxWarning',
#  'SystemError',
#  'SystemExit',
#  'TabError',
#  'TimeoutError',
#  'True',
#  'TypeError',
#  'UnboundLocalError',
#  'UnicodeDecodeError',
#  'UnicodeEncodeError',
#  'UnicodeError',
#  'UnicodeTranslateError',
#  'UnicodeWarning',
#  'UserWarning',
#  'ValueError',
#  'Warning',
#  'ZeroDivisionError',
#  '__IPYTHON__',
#  '__build_class__',
#  '__debug__',
#  '__doc__',
#  '__import__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'abs',
#  'aiter',
#  'all',
#  'anext',
#  'any',
#  'ascii',
#  'bin',
#  'bool',
#  'breakpoint',
#  'bytearray',
#  'bytes',
#  'callable',
#  'chr',
#  'classmethod',
#  'compile',
#  'complex',
#  'copyright',
#  'credits',
#  'delattr',
#  'dict',
#  'dir',
#  'display',
#  'divmod',
#  'enumerate',
#  'eval',
#  'exec',
#  'execfile',
#  'filter',
#  'float',
#  'format',
#  'frozenset',
#  'get_ipython',
#  'getattr',
#  'globals',
#  'hasattr',
#  'hash',
#  'help',
#  'hex',
#  'id',
#  'input',
#  'int',
#  'isinstance',
#  'issubclass',
#  'iter',
#  'len',
#  'license',
#  'list',
#  'locals',
#  'map',
#  'max',
#  'memoryview',
#  'min',
#  'next',
#  'object',
#  'oct',
#  'open',
#  'ord',
#  'pow',
#  'print',
#  'property',
#  'range',
#  'repr',
#  'reversed',
#  'round',
#  'runfile',
#  'set',
#  'setattr',
#  'slice',
#  'sorted',
#  'staticmethod',
#  'str',
#  'sum',
#  'super',
#  'tuple',
#  'type',
#  'vars',
#  'zip']

# %%
num1 = 10
#  num2 = 20  # IndentationError: unexpected indent

# %%
for i in range(20):
print(i)
# Out:
#   Cell In[6], line 2
#     print(i)
#     ^
# IndentationError: expected an indented block after 'for' statement on line 1

# %%
10 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 10 / 0
#
# ZeroDivisionError: division by zero

# %%
10 % 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 10 % 0
#
# ZeroDivisionError: integer modulo by zero

# %%
10 // 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 10 // 0
#
# ZeroDivisionError: integer division or modulo by zero

# %%
10 + '20'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 10 + '20'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
10.0 + '20'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 10.0 + '20'
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'

# %%
num1
# Out:
# 10

# %%
num1.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 num1.upper()
#
# AttributeError: 'int' object has no attribute 'upper'

# %%
mydict = {"a": "apple"}
mydict['b']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 2
#       1 mydict = {"a": "apple"}
# ----> 2 mydict['b']
#
# KeyError: 'b'

# %%
num3 = int(input('Enter number:'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 num3 = int(input('Enter number:'))  # 12.3
#
# ValueError: invalid literal for int() with base 10: '12.3'

# %% [markdown]
# Exception Handling
# FOUR blocks - try, except , else, finally
#                 mandatory      optional

# %%
try:
    num3 = int(input('Enter number:'))
    print(num3)
except:
    pass
# Out:
# 12

# %%
try:
    num3 = int(input('Enter number:'))
    print(num3)
except:
    pass
# Out:
# 12

# %%
try:
    num3 = int(input('Enter number:'))
    print(num3)
except:
    print('got error')
# Out:
# 13

# %%
try:
    num3 = int(input('Enter number:'))
    print(num3)
except Exception as ex:
    print(ex)
# Out:
# invalid literal for int() with base 10: '12.4'

# %%
try:
    num3 = int(input('Enter number:'))
    print(num3)
except Exception as ex:
    print(ex)
# Out:
# invalid literal for int() with base 10: 'none'

# %%
try:
    num3 = int(input('Enter number:'))
    print(num3)
except Exception as ex:
    print("ex      :", ex)
    print("str(ex) :", str(ex))
# Out:
# ex      : invalid literal for int() with base 10: 'ex'
# str(ex) : invalid literal for int() with base 10: 'ex'

# %%
try:
    num3 = int(input('Enter number:'))
    print(num3)
except Exception as ex:
    print("ex      :", ex)
    print("str(ex) :", str(ex))

    print("repr(ex):", repr(ex))
    print(f"{ex    = }")
# Out:
# ex      : invalid literal for int() with base 10: 'ex'
# str(ex) : invalid literal for int() with base 10: 'ex'
# repr(ex): ValueError("invalid literal for int() with base 10: 'ex'")
# ex    = ValueError("invalid literal for int() with base 10: 'ex'")

# %%
try:
    num3 = int(input('Enter number:'))
    print(num3)
except Exception as ex:
    print(dir(ex))
    print(f'{ex      =}')
    print(f'{ex.args =}')
# Out:
# ['__cause__', '__class__', '__context__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', '__suppress_context__', '__traceback__', 'add_note', 'args', 'with_traceback']
# ex      =ValueError("invalid literal for int() with base 10: 'ex'")
# ex.args =("invalid literal for int() with base 10: 'ex'",)

# %%
ex   # scope is within the exception block only
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 ex   # scope is within the exception block only
#
# NameError: name 'ex' is not defined

# %%
# Another example
# heirarychy of error 
try:
    10/ 0 
    10 // 0
    10 % 0 

    int(12)
    int(12.3)
    int('12.3')

    num1.upper()
except Exception as ex:
    print(f'{ex = }')
# Out:
# ex = ZeroDivisionError('division by zero')

# %%
# Note: Execution Order in Python: top to bottom, left to right
try:
    # 10/ 0 
    10 // 0
    10 % 0 

    int(12)
    int(12.3)
    int('12.3')

    num1.upper()
except Exception as ex:
    print(f'{ex = }')
# Out:
# ex = ZeroDivisionError('integer division or modulo by zero')

# %%
try:
    # 10/ 0 
    # 10 // 0
    10 % 0 

    int(12)
    int(12.3)
    int('12.3')

    num1.upper()
except Exception as ex:
    print(f'{ex = }')
# Out:
# ex = ZeroDivisionError('integer modulo by zero')

# %%
try:
    # 10/ 0 
    # 10 // 0
    # 10 % 0 

    int(12)
    int(12.3)
    int('12.3')

    num1.upper()
except Exception as ex:
    print(f'{ex = }')
# Out:
# ex = ValueError("invalid literal for int() with base 10: '12.3'")

# %%
try:
    # 10/ 0 
    # 10 // 0
    # 10 % 0 

    int(12)
    int(12.3)
    # int('12.3')

    num1.upper()
except Exception as ex:
    print(f'{ex = }')
# Out:
# ex = AttributeError("'int' object has no attribute 'upper'")

# %%
try:
    # 10/ 0 
    # 10 // 0
    # 10 % 0 

    int(12)
    int(12.3)
    # int('12.3')

    # num1.upper()
except Exception as ex:
    print(f'{ex = }')
else:
    print('No error .. all good')
# Out:
# No error .. all good

# %% [markdown]
# Exception flows
# when no error
#             try -> else -> finally
# when error
#             try -> except -> finally
#
#
# NOTE: else and finally blocks are optional
# NOTE:
#     1. code which we may result in errors need to be placed in try block
#     2. Error handling to corresponding errors need to be placed in except block
#     3. If no errors in try block, corresponding actions in else block
#     4. placeholder for all restrospective actions correspoding to that in try block
#         ex: in try block, socket/file/remote_connect/db_connection was opened
#             in finally block, we can close it

# %%
try:
    print("In try block")
    10 / int(input("Enter a number:")) # 10
except Exception as ex1:
    print(f"In Exception block: {ex1 =}")
else:
    print("In Else block")
finally:
    print("In finally block")

print("next statement")
# Out:
# In try block
# In Else block
# In finally block
# next statement

# %%
try:
    print("In try block")
    10 / int(input("Enter a number:")) # 0
except Exception as ex1:
    print(f"In Exception block: {ex1 =}")
else:
    print("In Else block")
finally:
    print("In finally block")

print("next statement")
# Out:
# In try block
# In Else block
# In finally block
# next statement

# %%
try:
    print("In try block")
    10 /0
    10 / int(input("Enter a number:"))
except Exception as ex1:
    print(f"In Exception block: {ex1 =}")
else:
    print("In Else block")
finally:
    print("In finally block")

print("next statement")
# Out:
# In try block
# In Exception block: ex1 =ZeroDivisionError('division by zero')
# In finally block
# next statement

# %%
# # case 1 -- 5  ==========================> NO EXCEPTION
# - python 03_exception_handling.py
# In try block
# Enter a number:5
# In Else block
# In finally block
# next statement

# # case 2 -- 0 ============================> ZeroDivisionError
# - python 03_exception_handling.py
# In try block
# Enter a number:0
# In Exception block: ex1 =ZeroDivisionError('division by zero')
# In finally block
# next statement


# # case 3 -- 5.3  ==========================> ValueError
# - python 03_exception_handling.py
# In try block
# Enter a number:5.3
# In Exception block: ex1 =ValueError("invalid literal for int() with base 10: '5.3'")
# In finally block
# next statement

# %% [markdown]
# ### Importance of "else" block

# %%
# Case 1 - without exception handling
num1 = 1000
num2 = 2022

add_result = num1 + num2
print(f"{add_result = }")
# Out:
# add_result = 3022

# %%
num1 = 1000
num2 = "2022"

add_result = num1 + num2
print(f"{add_result = }")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 4
#       1 num1 = 1000
#       2 num2 = "2022"
# ----> 4 add_result = num1 + num2
#       5 print(f"{add_result = }")
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
num1 = 1000
num2 = "2022"

try:
    add_result = num1 + num2
except Exception as ex:
    print(f'{ex =}')
else:
    print(f"{add_result = }")
# Out:
# ex =TypeError("unsupported operand type(s) for +: 'int' and 'str'")

# %%
num1 = 1000
num2 = 2022

try:
    add_result = num1 + num2
except Exception as ex:
    print(f'{ex =}')
else:
    print(f"{add_result = }")
# Out:
# add_result = 3022

# %% [markdown]
# ### Another example

# %%
num1 = int(input("Enter an integer:"))
num2 = int(input("Enter an integer:"))
print(f'{num1 = }')
print(f'{num2 = }')

try:
    add_result = num1 + num2
except Exception as ex:
    print(f'{ex =}')
else:
    print(f"{add_result = }")
# Out:
# num1 = 5
# num2 = 6
# add_result = 11

# %%
num1 = int(input("Enter an integer:"))
num2 = int(input("Enter an integer:"))
print(f'{num1 = }')
print(f'{num2 = }')

try:
    add_result = num1 + num2
except Exception as ex:
    print(f'{ex =}')
else:
    print(f"{add_result = }")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 2
#       1 num1 = int(input("Enter an integer:"))
# ----> 2 num2 = int(input("Enter an integer:"))
#       3 print(f'{num1 = }')
#       4 print(f'{num2 = }')
#
# ValueError: invalid literal for int() with base 10: '222.22'

# %%
try:
    num1 = int(input("Enter an integer:"))
    num2 = int(input("Enter an integer:"))
except Exception as ex:
    print(f'{ex =}')
else:
    print(f'{num1 = }')
    print(f'{num2 = }')
    add_result = num1 + num2
    print(f"{add_result = }")
# Out:
# ex =ValueError("invalid literal for int() with base 10: '223.32'")

# %%
try:
    num1 = int(input("Enter an integer:"))
    num2 = int(input("Enter an integer:"))
except Exception as ex:
    print(f'{ex =}')
else:
    print(f'{num1 = }')
    print(f'{num2 = }')
    add_result = num1 + num2
    print(f"{add_result = }")
# Out:
# num1 = 2313
# num2 = 23456
# add_result = 25769

# %%
# extended example
try:
    num1 = int(input("Enter an integer:"))
    num2 = int(input("Enter an integer:"))
except Exception as ex:
    print(f'{ex =}')
else:
    print(f'{num1 = }')
    print(f'{num2 = }')
    add_result = num1 / num2
    print(f"{add_result = }")
# Out:
# num1 = 100
# num2 = 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[43], line 10
#       8 print(f'{num1 = }')
#       9 print(f'{num2 = }')
# ---> 10 add_result = num1 / num2
#      11 print(f"{add_result = }")
#
# ZeroDivisionError: division by zero

# %%
# Multi-level exceptions
try:
    num1 = int(input("Enter an integer:"))
    num2 = int(input("Enter an integer:"))
except Exception as ex:
    print(f'{ex =}')
else:
    print(f'{num1 = }')
    print(f'{num2 = }')

    try:
        add_result = num1 / num2
    except Exception as ex1:
        print(f'{ex1 =}')
    else:
        print(f"{add_result = }")
# Out:
# num1 = 100
# num2 = 0
# ex1 =ZeroDivisionError('division by zero')

# %%
# Handling Multiple exceptions
try:
    num1 = int(input("Enter an integer:"))
    num2 = int(input("Enter an integer:"))
    division = num1 / num2
except Exception as ex:
    print(f"{ex =}")
    print("Please enter integers only (or) denominator is 0")
else:
    print(f"{division = }")
# Out:
# division = 0.5

# %%
try:
    num1 = int(input("Enter an integer:"))
    num2 = int(input("Enter an integer:"))
    division = num1 / num2
except Exception as ex:
    print(f"Unhandled Exception: {ex =}")
except ValueError as ve:
    print(f"{ve =}")
    print("Please enter integers only")
except ZeroDivisionError as ze:
    print(f"{ze =}")
    print("Denominator should be NON-zero")

else:
    print(f"{division = }")

# top to bottom check happends
# Out:
# Unhandled Exception: ex =ValueError("invalid literal for int() with base 10: '67.32'")

# %%
try:
    num1 = int(input("Enter an integer:"))
    num2 = int(input("Enter an integer:"))
    division = num1 / num2
except Exception as ex:
    print(f"Unhandled Exception: {ex =}")
except ValueError as ve:
    print(f"{ve =}")
    print("Please enter integers only")
except ZeroDivisionError as ze:
    print(f"{ze =}")
    print("Denominator should be NON-zero")

else:
    print(f"{division = }")

# top to bottom check happends
# Out:
# Unhandled Exception: ex =ZeroDivisionError('division by zero')

# %%
try:
    num1 = int(input("Enter an integer:"))
    num2 = int(input("Enter an integer:"))
    division = num1 / num2
except ValueError as ve:
    print(f"{ve =}")
    print("Please enter integers only")
except ZeroDivisionError as ze:
    print(f"{ze =}")
    print("Denominator should be NON-zero")
except Exception as ex:
    print(f"Unhandled Exception: {ex =}")
else:
    print(f"{division = }")

# top to bottom check happends
# Out:
# ve =ValueError("invalid literal for int() with base 10: '47.2432'")
# Please enter integers only

# %%
try:
    num1 = int(input("Enter an integer:"))
    num2 = int(input("Enter an integer:"))
    division = num1 / num2
except ValueError as ve:
    print(f"{ve =}")
    print("Please enter integers only")
except ZeroDivisionError as ze:
    print(f"{ze =}")
    print("Denominator should be NON-zero")
except Exception as ex:
    print(f"Unhandled Exception: {ex =}")
else:
    print(f"{division = }")

# top to bottom check happends
# Out:
# ze =ZeroDivisionError('division by zero')
# Denominator should be NON-zero

# %%
# NOTE: Though we handle with specific exception based on seen errors,
# It is always recommended to have absolute(umbrella) exception to
# handle any unknown runtime errors.

# NOTE: exception handling should be defined from lower to higher hierarchy.

# %%
try:
    num1 = int(input("Enter an integer:"))
    num2 = int(input("Enter an integer:"))
    division = num1 / num2
except ValueError as ve:
    print(f"{ve =}")
    print("Please enter integers only")
except ArithmeticError as ae: 
    print(f'{ae = }')
    print('Arithmetic error - can be FloatingPointError, or OverflowError or zero error')
except ZeroDivisionError as ze:
    print(f"{ze =}")
    print("Denominator should be NON-zero")
except Exception as ex:
    print(f"Unhandled Exception: {ex =}")
else:
    print(f"{division = }")

# top to bottom check happends
# Out:
# ae = ZeroDivisionError('division by zero')
# Arithmetic error - can be FloatingPointError, or OverflowError or zero error

# %% [markdown]
# Assertions
# Useful in unit testing/ pytest
# Validates the given condition
#
# SYNTAX:
#
#     assert <condition>, "<exception message if condition is incorrect>"

# %%
print(f"{10 + 2}")
print(f"{10 + 2 =}")
print(f"{10 + 2 == 12}")
# Out:
# 12
# 10 + 2 =12
# True

# %%
if 10 + 2 == 12:
    print("This is True")
else:
    print("This is not correct")
# Out:
# This is True

# %%
assert 2 + 10 == 12, "Wrong answer"

# %%
assert 10 + 2 == 12, "Wrong answer"

# %%
assert 10 + 12 == 12, "Wrong answer"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 assert 10 + 12 == 12, "Wrong answer"
#
# AssertionError: Wrong answer

# %%
try:
    assert 12 + 10 == 12, "Wrong answer"
except AssertionError as ex:
    print(f"{ex =}")
# Out:
# ex =AssertionError('Wrong answer')

# %% [markdown]
# #### Raising exceptions

# %%
raise
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 raise
#
# RuntimeError: No active exception to reraise

# %%
raise Exception()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 raise Exception()
#
# Exception:

# %%
raise Exception('This is an error')
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 raise Exception('This is an error')
#
# Exception: This is an error

# %%
raise ValueError()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 raise ValueError()
#
# ValueError:

# %%
raise TypeError()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 raise TypeError()
#
# TypeError:

# %%
raise NameError('This is name error')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 raise NameError('This is name error')
#
# NameError: This is name error

# %%
try:
    raise NameError('This is name error')
except Exception as ex:
    print(f'{ex = }')
# Out:
# ex = NameError('This is name error')

# %%
try:
    raise NameError("This is name error")
except NameError as ne:
    print(f"{ne =}")
# Out:
# ne =NameError('This is name error')

# %%
try:
    raise NameError('This is name error')
except NameError as ne:
    ne.add_note("PLEASE ENSURE NOT TO REPEAT")
    raise
    print(f"{ne =}")  # NOT REACHABLE
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[67], line 2
#       1 try:
# ----> 2     raise NameError('This is name error')
#       3 except NameError as ne:
#       4     ne.add_note("PLEASE ENSURE NOT TO REPEAT")
#
# NameError: This is name error
# PLEASE ENSURE NOT TO REPEAT

# %%
try:
    try:
        raise NameError("This is name error")
    except NameError as ne:
        ne.add_note("PLEASE ENSURE NOT TO REPEAT")
        raise
        # print(f"{ne =}")  # NOT REACHABLE
except Exception as ex:
    print(f"{ex =}")
# Out:
# ex =NameError('This is name error')

# %%
# Assignment - try to get both these exception notes to the final exception message
try:
    num = int(input("Enter a number: "))
    result = 10 / num
except Exception as err:
    err.add_note("First Note: Error occurred while processing user input.")
    err.add_note("Second Note: Please enter a non-zero integer.")
    raise
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[69], line 4
#       2 try:
#       3     num = int(input("Enter a number: "))
# ----> 4     result = 10 / num
#       5 except Exception as err:
#       6     err.add_note("First Note: Error occurred while processing user input.")
#
# ZeroDivisionError: division by zero
# First Note: Error occurred while processing user input.
# Second Note: Please enter a non-zero integer.

# %%
try:
    num1 = int(input("Enter an integer:"))
    num2 = int(input("Enter an integer:"))
    if num2 == 0:
        # raise Exception("Ensure that num2 is NON-ZERO")
        raise ZeroDivisionError("Ensure that num2 is NON-ZERO")
except ZeroDivisionError as ze:
    print(repr(ze))
except Exception as ex:
    print(repr(ex))
else:
    division = num1 / num2
    print(f"{division =}")
# Out:
# ZeroDivisionError('Ensure that num2 is NON-ZERO')

# %% [markdown]
# Finally block usage
# - its just a placeholder. it will execute  in both cases - when exception and when no exception

# %%
try:
    fh = open('myfile.txt', 'w')
except Exception as ex:
    print(ex)
else:
    fh.write('myfile')
finally:
    fh.close()  # Janitor / cleaup action

# %% [markdown]
# ##### exception traceback

# %%
num1 = 12
num2 = 34
num3 = 456
num4 = "34"
num5 = 3445

try:
    expr1 = num1 / num2 - num3
    expr2 = num2 * num4 / num3
    expr3 = num2 - num4
    expr4 = expr1 * (expr2) / expr3
except ZeroDivisionError:
    print("Denominator in divison should not be zero")
except Exception as ex:
    print(f"Unhandled exception:{ex =}")
# Out:
# Unhandled exception:ex =TypeError("unsupported operand type(s) for /: 'str' and 'int'")

# %%
import sys

num1 = 12
num2 = 34
num3 = 456
num4 = "34"
num5 = 3445

try:
    expr1 = num1 / num2 - num3
    expr2 = num2 * num4 / num3
    expr3 = num2 - num4
    expr4 = expr1 * (expr2) / expr3
except ZeroDivisionError:
    print("Denominator in divison should not be zero")
except Exception as ex:
    print(f"Unhandled exception:{ex =}")
    print(" sys.exc_info()",  sys.exc_info())
# Out:
# Unhandled exception:ex =TypeError("unsupported operand type(s) for /: 'str' and 'int'")
#  sys.exc_info() (<class 'TypeError'>, TypeError("unsupported operand type(s) for /: 'str' and 'int'"), <traceback object at 0x7dc5c4adbac0>)

# %%
import sys

num1 = 12
num2 = 34
num3 = 456
num4 = "34"
num5 = 3445

try:
    expr1 = num1 / num2 - num3
    expr2 = num2 * num4 / num3
    expr3 = num2 - num4
    expr4 = expr1 * (expr2) / expr3
except ZeroDivisionError:
    print("Denominator in divison should not be zero")
except Exception as ex:
    print(f"Unhandled exception:{ex =}")
    # print(" sys.exc_info()",  sys.exc_info())
    exc_type, exc_value, exc_traceback = sys.exc_info()  # TUPLE UNPACKING

    print(
        f"""
    exc_type     : {exc_type},
    exc_value    : {exc_value},
    exc_traceback: {exc_traceback},
    """)
# Out:
# Unhandled exception:ex =TypeError("unsupported operand type(s) for /: 'str' and 'int'")
#
#     exc_type     : <class 'TypeError'>,
#     exc_value    : unsupported operand type(s) for /: 'str' and 'int',
#     exc_traceback: <traceback object at 0x7dc5c4c291c0>,

# %%
import traceback

dir(traceback)
# Out:
# ['FrameSummary',
#  'StackSummary',
#  'TracebackException',
#  '_Anchors',
#  '_CASE_COST',
#  '_ExceptionPrintContext',
#  '_MAX_CANDIDATE_ITEMS',
#  '_MAX_STRING_SIZE',
#  '_MOVE_COST',
#  '_RECURSIVE_CUTOFF',
#  '_Sentinel',
#  '_WIDE_CHAR_SPECIFIERS',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_byte_offset_to_character_offset',
#  '_cause_message',
#  '_compute_suggestion_error',
#  '_context_message',
#  '_display_width',
#  '_extract_caret_anchors_from_line_segment',
#  '_format_final_exc_line',
#  '_get_code_position',
#  '_levenshtein_distance',
#  '_parse_value_tb',
#  '_safe_string',
#  '_sentinel',
#  '_substitution_cost',
#  '_walk_tb_with_full_positions',
#  'clear_frames',
#  'collections',
#  'extract_stack',
#  'extract_tb',
#  'format_exc',
#  'format_exception',
#  'format_exception_only',
#  'format_list',
#  'format_stack',
#  'format_tb',
#  'itertools',
#  'linecache',
#  'print_exc',
#  'print_exception',
#  'print_last',
#  'print_list',
#  'print_stack',
#  'print_tb',
#  'suppress',
#  'sys',
#  'textwrap',
#  'walk_stack',
#  'walk_tb']

# %%
import sys

num1 = 12
num2 = 34
num3 = 456
num4 = "34"
num5 = 3445

try:
    expr1 = num1 / num2 - num3
    expr2 = num2 * num4 / num3
    expr3 = num2 - num4
    expr4 = expr1 * (expr2) / expr3
except ZeroDivisionError:
    print("Denominator in divison should not be zero")
except Exception as ex:
    print(f"Unhandled exception:{ex =}")
    # print(" sys.exc_info()",  sys.exc_info())
    exc_type, exc_value, exc_traceback = sys.exc_info()  # TUPLE UNPACKING

    print(
        f"""
    exc_type     : {exc_type},
    exc_value    : {exc_value},
    exc_traceback: {exc_traceback},
        Error Line: {exc_traceback.tb_lineno},
        tb_lasti  : {exc_traceback.tb_lasti},
        tb_next   : {exc_traceback.tb_next}
        tb_frame  : {exc_traceback.tb_frame},
    """)
# Out:
# Unhandled exception:ex =TypeError("unsupported operand type(s) for /: 'str' and 'int'")
#
#     exc_type     : <class 'TypeError'>,
#     exc_value    : unsupported operand type(s) for /: 'str' and 'int',
#     exc_traceback: <traceback object at 0x7dc5c5a70440>,
#         Error Line: 11,
#         tb_lasti  : 30,
#         tb_next   : None
#         tb_frame  : <frame at 0x7dc5c5a52e60, file '/tmp/ipykernel_7189/3987069882.py', line 29, code <module>>,

# %%
import traceback
import sys

num1 = 12
num2 = 34
num3 = 456
num4 = "34"
num5 = 3445

try:
    expr1 = num1 / num2 - num3
    expr2 = num2 * num4 / num3
    expr3 = num2 - num4
    expr4 = expr1 * (expr2) / expr3
except ZeroDivisionError:
    print("Denominator in divison should not be zero")
except Exception as ex:
    print(f"Unhandled exception:{ex =}")
    # print(" sys.exc_info()",  sys.exc_info())
    exc_type, exc_value, exc_traceback = sys.exc_info()  # TUPLE UNPACKING

    print(
        f"""
    exc_type     : {exc_type},
    exc_value    : {exc_value},
    exc_traceback: {exc_traceback},
        Error Line: {exc_traceback.tb_lineno},
        tb_lasti  : {exc_traceback.tb_lasti},
        tb_next   : {exc_traceback.tb_next}
        tb_frame  : {exc_traceback.tb_frame},
    """)
    print()
    traceback.print_exc(file=sys.stdout)
# Out:
# Unhandled exception:ex =TypeError("unsupported operand type(s) for /: 'str' and 'int'")
#
#     exc_type     : <class 'TypeError'>,
#     exc_value    : unsupported operand type(s) for /: 'str' and 'int',
#     exc_traceback: <traceback object at 0x7dc5c5a736c0>,
#         Error Line: 12,
#         tb_lasti  : 30,
#         tb_next   : None
#         tb_frame  : <frame at 0x7dc5c5a53400, file '/tmp/ipykernel_7189/438986148.py', line 30, code <module>>,
#
#
# Traceback (most recent call last):
#   File "/tmp/ipykernel_7189/438986148.py", line 12, in <module>
#     expr2 = num2 * num4 / num3
#             ~~~~~~~~~~~~^~~~~~
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
import sys
import traceback

num1 = 12
num2 = 34
num3 = 456
num4 = "34"
num5 = 3445

try:
    expr1 = num1 / num2 - num3
    expr2 = num2 * num4 / num3
    expr3 = num2 - num4
    expr4 = expr1 * (expr2) / expr3
except ZeroDivisionError:
    print("Denominator in divison should not be zero")
except Exception as ex:
    print(f"Unhandled exception:{ex =}")
    # print(" sys.exc_info()",  sys.exc_info())
    exc_type, exc_value, exc_traceback = sys.exc_info()  # TUPLE UNPACKING

    print(
        f"""
    exc_type     : {exc_type},
    exc_value    : {exc_value},
    exc_traceback: {exc_traceback},
        Error Line: {exc_traceback.tb_lineno},
        tb_lasti  : {exc_traceback.tb_lasti},
        tb_next   : {exc_traceback.tb_next}
        tb_frame  : {exc_traceback.tb_frame},
    """
    )
    print()
    traceback.print_exc(file=sys.stdout)
else:
    print(f"{expr4 =}")
finally:
    print("Finally block")

print("next Statement")
# Out:
# Unhandled exception:ex =TypeError("unsupported operand type(s) for /: 'str' and 'int'")
#
#     exc_type     : <class 'TypeError'>,
#     exc_value    : unsupported operand type(s) for /: 'str' and 'int',
#     exc_traceback: <traceback object at 0x7dc5c4ad9000>,
#         Error Line: 12,
#         tb_lasti  : 30,
#         tb_next   : None
#         tb_frame  : <frame at 0x7dc5c5a51ea0, file '/tmp/ipykernel_7189/1666058202.py', line 30, code <module>>,
#
#
# Traceback (most recent call last):
#   File "/tmp/ipykernel_7189/1666058202.py", line 12, in <module>
#     expr2 = num2 * num4 / num3
#             ~~~~~~~~~~~~^~~~~~
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
# Finally block
# next Statement

# %% [markdown]
# #### custom_exception

# %%
# Method 1 - stop when exception is raised
try:
    votes = 0
    i = 0
    while i < 5:
        age = int(input('Enter your age:'))
        if age <= 0:
            raise Exception('Invalid Entry for the age!')
        elif age < 18:
            raise Exception('You are Ineligible to vote!!')
        else:
            votes += 1
        i += 1
except Exception as ex:
    print(f'{ex=}')

print(f"Total Eligible Voters: {votes}")
# Out:
# ex=Exception('You are Ineligible to vote!!')
# Total Eligible Voters: 0

# %%
# Method 2 - skip the loop with exception
class InvalidInput(Exception):
    pass


class InvalidAge(Exception):
    pass



votes = 0
attempt = 0
while attempt < 5:
    print(f"\n{attempt =}")
    try:
        age = int(input("Enter your age:"))
        if age <= 0:
            raise InvalidInput("Invalid Entry for the age!")
        elif age < 18:
            # raise InvalidAge('You are Ineligible to vote!!')
            raise InvalidAge(f"You are short by {18 - age} years for voting")
        else:
            votes += 1
        attempt += 1
    except Exception as ex:
        print(f"{ex=}")
    else:
        print(f"Your voterID is {attempt}")
# Out:
# attempt =0
# ex=InvalidInput('Invalid Entry for the age!')
#
# attempt =0
# ex=InvalidInput('Invalid Entry for the age!')
#
# attempt =0
# ex=InvalidInput('Invalid Entry for the age!')
#
# attempt =0
# ex=ValueError("invalid literal for int() with base 10: '-'")
#
# attempt =0
# ex=InvalidInput('Invalid Entry for the age!')
#
# attempt =0
# ex=InvalidInput('Invalid Entry for the age!')
#
# attempt =0
# ex=InvalidInput('Invalid Entry for the age!')
#
# attempt =0
# ex=InvalidInput('Invalid Entry for the age!')
#
# attempt =0
# ex=InvalidInput('Invalid Entry for the age!')
#
# attempt =0
# ex=InvalidInput('Invalid Entry for the age!')
#
# attempt =0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[81], line 16
#      14 print(f"\n{attempt =}")
#      15 try:
# ---> 16     age = int(input("Enter your age:"))
#      17     if age <= 0:
#      18         raise InvalidInput("Invalid Entry for the age!")
#
# File ~/.local/lib/python3.12/site-packages/ipykernel/kernelbase.py:1403, in Kernel.raw_input(self, prompt)
#    1401     msg = "raw_input was called, but this frontend does not support input requests."
#    1402     raise StdinNotImplementedError(msg)
# -> 1403 return self._input_request(
#    1404     str(prompt),
#    1405     self._get_shell_context_var(self._shell_parent_ident),
#    1406     self.get_parent("shell"),
#    1407     password=False,
#    1408 )
#
# File ~/.local/lib/python3.12/site-packages/ipykernel/kernelbase.py:1448, in Kernel._input_request(self, prompt, ident, parent, password)
#    1445 except KeyboardInterrupt:
#    1446     # re-raise KeyboardInterrupt, to truncate traceback
#    1447     msg = "Interrupted by user"
# -> 1448     raise KeyboardInterrupt(msg) from None
#    1449 except Exception:
#    1450     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
# Assignment - enhance this example to take and validate the all the 5 values and give finally summary of valid and invalid votes
valid_votes = 0
invalid_votes = 0

for i in range(1, 6):
    try:
        age = int(input(f"Enter age of voter {i}: "))

        if age < 18:
            raise ValueError("Not eligible to vote")

        print(f"Voter {i}: Valid Vote")
        valid_votes += 1

    except ValueError as err:
        print(f"Voter {i}: Invalid Vote - {err}")
        invalid_votes += 1

print("\n===== Voting Summary =====")
print(f"Total Voters : 5")
print(f"Valid Votes  : {valid_votes}")
print(f"Invalid Votes: {invalid_votes}")
# Out:
# Voter 1: Valid Vote
# Voter 2: Invalid Vote - Not eligible to vote
# Voter 3: Invalid Vote - invalid literal for int() with base 10: 'abc'
# Voter 4: Valid Vote
# Voter 5: Invalid Vote - Not eligible to vote
#
# ===== Voting Summary =====
# Total Voters : 5
# Valid Votes  : 2
# Invalid Votes: 3

# %% [markdown]
# Exception Groups
# introduced in Python 3.11
# PEP 654 - Exception Groups and except*

# %%
print("\n CASE 1")
try:
    raise ValueError("This is Value Error")
    raise TypeError("This is type Error")
except ValueError as ex:
    print(f"{ex =}")
# Out:
#  CASE 1
# ex =ValueError('This is Value Error')

# %%
raise ValueError("This is Value Error")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 raise ValueError("This is Value Error")
#
# ValueError: This is Value Error

# %%
raise ExceptionGroup(
    "It can both Value & Type Errors",
    [
        ValueError(1),
        TypeError(2),
    ],
)
# Out:
#   + Exception Group Traceback (most recent call last):
#   |   File "/home/codespace/.local/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3747, in run_code
#   |     exec(code_obj, self.user_global_ns, self.user_ns)
#   |   File "/tmp/ipykernel_7189/1416085930.py", line 1, in <module>
#   |     raise ExceptionGroup(
#   | ExceptionGroup: It can both Value & Type Errors (2 sub-exceptions)
#   +-+---------------- 1 ----------------
#     | ValueError: 1
#     +---------------- 2 ----------------
#     | TypeError: 2
#     +------------------------------------

# %%
print("\n CASE 2")
try:
    raise ExceptionGroup(
        "It can both Value & Type Errors",
        [
            ValueError(1),
            TypeError(2),
        ],
    )
except ValueError as ve:
    print(f"Value Error: {ve =}")
except TypeError as te:
    print(f"Type Error: {te =}")
except Exception as ex:
    print(f"UnHandled Exception: {ex =}")

# NOTE: ExceptionGroup cant be handled by individual exception types
# Out:
#  CASE 2
# UnHandled Exception: ex =ExceptionGroup('It can both Value & Type Errors', [ValueError(1), TypeError(2)])

# %%
print("\n CASE 3")
try:
    raise ExceptionGroup(
        "It can both Value & Type Errors",
        [
            ValueError(1),
            TypeError(2),
        ],
    )
except (ValueError, TypeError) as ve:
    print(f"Value or type Error: {ve =}")
except Exception as ex:
    print(f"UnHandled Exception: {ex =}")

# NOTE: ExceptionGroup cant be handled by individual exception types
# Out:
#  CASE 3
# UnHandled Exception: ex =ExceptionGroup('It can both Value & Type Errors', [ValueError(1), TypeError(2)])

# %%
print("\n CASE 4")
try:
    raise ExceptionGroup(
        "It can both Value & Type Errors",
        [
            ValueError(1),
            TypeError(2),
        ],
    )
except* ValueError as ve:
    print(f"Value Error: {ve =}")
except* TypeError as te:
    print(f"Type Error: {te =}")
except* Exception as ex:
    print(f"UnHandled Exception: {ex =}")

# NOTE: except* & except CANT BE used within same try-except blocks
# Out:
#  CASE 4
# Value Error: ve =ExceptionGroup('It can both Value & Type Errors', [ValueError(1)])
# Type Error: te =ExceptionGroup('It can both Value & Type Errors', [TypeError(2)])

# %%
print("\n CASE 5")
try:
    raise ExceptionGroup(
        "It can both Value & Type Errors",
        [
            TypeError(2),
            ValueError(1),
        ],
    )
except* ValueError as ve:
    print(f"Value Error: {ve =}")
except* TypeError as te:
    print(f"Type Error: {te =}")
except* Exception as ex:
    print(f"UnHandled Exception: {ex =}")

# NOTE: except* & except CANT BE used within same try-except blocks
# Out:
#  CASE 5
# Value Error: ve =ExceptionGroup('It can both Value & Type Errors', [ValueError(1)])
# Type Error: te =ExceptionGroup('It can both Value & Type Errors', [TypeError(2)])

# %%
print("\n CASE 6")
try:
    raise ExceptionGroup(
        "It can both Value & Type Errors",
        [
            ValueError(1),
            TypeError(2),
            OSError(3),  # Added New Exception
        ],
    )
except* ValueError as ve:
    print(f"Value Error: {ve =}")
except* TypeError as te:
    print(f"Type Error: {te =}")
except* Exception as ex:
    print(f"UnHandled Exception: {ex =}")
# Out:
#  CASE 6
# Value Error: ve =ExceptionGroup('It can both Value & Type Errors', [ValueError(1)])
# Type Error: te =ExceptionGroup('It can both Value & Type Errors', [TypeError(2)])
# UnHandled Exception: ex =ExceptionGroup('It can both Value & Type Errors', [OSError(3)])

# %%
print("\n CASE 7")
try:
    raise ExceptionGroup(
        "It can both Value & Type Errors",
        [
            ValueError(1),
            TypeError(2),
            OSError(3),  # Added New Exception
            ExceptionGroup(
                "Another group",  # Second group inside main group
                [Exception("Another error")],
            ),
        ],
    )
except* ValueError as ve:
    print(f"Value Error: {ve =}")
except* TypeError as te:
    print(f"Type Error: {te =}")
except* OSError as te:
    print(f"OS Error: {te =}")
except* Exception as ex:
    print(f"UnHandled Exception: {ex =}")
# Out:
#  CASE 7
# Value Error: ve =ExceptionGroup('It can both Value & Type Errors', [ValueError(1)])
# Type Error: te =ExceptionGroup('It can both Value & Type Errors', [TypeError(2)])
# OS Error: te =ExceptionGroup('It can both Value & Type Errors', [OSError(3)])
# UnHandled Exception: ex =ExceptionGroup('It can both Value & Type Errors', [ExceptionGroup('Another group', [Exception('Another error')])])

# %%
print("\n CASE 8")
try:
    raise ExceptionGroup(
        "It can both Value & Type Errors",
        [
            ValueError(1),
            TypeError(2),
            OSError(3),  # Added New Exception
            ExceptionGroup(
                "Another group",  # Second group inside main group
                [Exception("Another error")],
            ),
            ExceptionGroup("nested", [OSError(4), TypeError(5), ValueError(6)]),
        ],
    )
except* ValueError as ve:
    print(f"Value Error: {ve =}")
except* TypeError as te:
    print(f"Type Error: {te =}")
except* Exception as ex:
    print(f"UnHandled Exception: {ex =}")
    try:
        ex_subgroup = ex.subgroup(1)
        # this call will throw error, if exception in subgroup
    except* Exception as sub_ex:
        print(f"\tSubGroup Error {sub_ex =}")
# Out:
#  CASE 8
# Value Error: ve =ExceptionGroup('It can both Value & Type Errors', [ValueError(1), ExceptionGroup('nested', [ValueError(6)])])
# Type Error: te =ExceptionGroup('It can both Value & Type Errors', [TypeError(2), ExceptionGroup('nested', [TypeError(5)])])
# UnHandled Exception: ex =ExceptionGroup('It can both Value & Type Errors', [OSError(3), ExceptionGroup('Another group', [Exception('Another error')]), ExceptionGroup('nested', [OSError(4)])])
# 	SubGroup Error sub_ex =ExceptionGroup('', (TypeError('expected a function, exception type or tuple of exception types'),))

# %%
print("\n CASE 7")
try:
    try:
        raise ExceptionGroup(
            "eg",
            [
                ValueError(1),
                TypeError(2),
                OSError(3),
                ExceptionGroup("nested", [OSError(4), TypeError(5), ValueError(6)]),
            ],
        )
    except* ValueError as e:
        print(f"*ValueError: {e!r}")
        raise
    except* OSError as e:
        print(f"*OSError: {e!r}")
except ExceptionGroup as e:
    print(repr(e))
# Out:
#  CASE 7
# *ValueError: ExceptionGroup('eg', [ValueError(1), ExceptionGroup('nested', [ValueError(6)])])
# *OSError: ExceptionGroup('eg', [OSError(3), ExceptionGroup('nested', [OSError(4)])])
# ExceptionGroup('eg', [ValueError(1), TypeError(2), ExceptionGroup('nested', [TypeError(5), ValueError(6)])])

# %%
## Warnings
#!/usr/bin/python3
"""
Purpose: Handling warnings
"""
import warnings

for each_attribute in dir(warnings):
    if not each_attribute.startswith("_"):
        print(each_attribute)
print()

warnings.warn("This is not good practice 1")

# Adding filter to display on specific warnings
warnings.filterwarnings(
    "ignore",
    ".*do not.*",
)

warnings.warn("This warning will be displayed")
warnings.warn("Do not show this message")
print()

try:
    # To throw exception when error warning is present
    warnings.simplefilter("error", UserWarning)
    warnings.warn("This is not good practice 2")
except UserWarning as ex:
    print(repr(ex))
except Exception as ex:
    print("Unhandled Exception", repr(ex))
# Out:
# WarningMessage
# catch_warnings
# defaultaction
# filters
# filterwarnings
# formatwarning
# onceregistry
# resetwarnings
# showwarning
# simplefilter
# sys
# warn
# warn_explicit
#
#
# UserWarning('This is not good practice 2')
# /tmp/ipykernel_7189/2613415897.py:13: UserWarning: This is not good practice 1
#   warnings.warn("This is not good practice 1")
# /tmp/ipykernel_7189/2613415897.py:21: UserWarning: This warning will be displayed
#   warnings.warn("This warning will be displayed")
